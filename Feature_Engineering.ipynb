# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_test=pd.read_csv('/content/Test-1542969243754.csv')
df_test_bene=pd.read_csv('/content/Test_Beneficiarydata-1542969243754.csv')
df_test_ip=pd.read_csv('/content/Test_Inpatientdata-1542969243754.csv')
df_test_op=pd.read_csv('/content/Test_Outpatientdata-1542969243754.csv')
df_train=pd.read_csv('/content/Train-1542865627584.csv')
df_train_bene=pd.read_csv('/content/Train_Beneficiarydata-1542865627584.csv')
df_train_ip=pd.read_csv('/content/Train_Inpatientdata-1542865627584.csv')
df_train_op=pd.read_csv('/content/Train_Outpatientdata-1542865627584.csv')

# %%
print(df_test.shape)
print(df_test_bene.shape)
print(df_test_ip.shape)
print(df_test_op.shape)
# Out:
# (1353, 1)
# (63968, 25)
# (9551, 30)
# (125841, 27)

# %%
print(df_train.shape)
print(df_train_bene.shape)
print(df_train_ip.shape)
print(df_train_op.shape)
# Out:
# (5410, 2)
# (138556, 25)
# (40474, 30)
# (517737, 27)

# %%
fig = df_train["PotentialFraud"].value_counts().plot(kind='bar', color=['green','orange'])
for p in fig.patches:
  width = p.get_width()
  height = p.get_height()
  x, y = p.get_xy()
  fig.annotate(f'{str(round((height*100)/df_train.shape[0],2))+"%"}', (x + width/2, y + height*1.015), ha='center', fontsize=8.5)

# %% [markdown]
# Adding feature 1: admitted or not indicator IP & OP datasets

# %%
df_train_ip['admitted']=1
df_train_op['admitted']=0

# %% [markdown]
# Merging data sets

# %%
# common columns
common_cols = list(set(df_train_ip.columns).intersection(df_train_op.columns))
len(common_cols)
# Out:
# 28

# %%
# Merging the IP and OP dataset on the basis of common columns
train_ip_op_df = pd.merge(left=df_train_ip, right=df_train_op, left_on=common_cols, right_on=common_cols, how="outer")
train_ip_op_df.shape
# Out:
# (558211, 31)

# %%
train_ip_op_df.head()
# Out:
#        BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE112023  CLM56135   2009-06-18  2009-06-19  PRV55849
# 1   BENE54949  CLM72036   2009-10-15  2009-10-17  PRV55518
# 2   BENE15268  CLM43437   2009-03-21  2009-03-24  PRV52281
# 3   BENE54966  CLM57034   2009-06-25  2009-06-28  PRV57103
# 4   BENE68657  CLM31205   2008-12-24  2009-01-03  PRV51501
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   10000          PHY402314          PHY396032
# 1                   31000          PHY393893          PHY346680
# 2                   12000          PHY398379          PHY397781
# 3                       0          PHY383675          PHY312883
# 4                   26000          PHY327234          PHY348953
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0            NaN  2009-06-18  ...                NaN                 NaN
# 1            NaN  2009-10-15  ...                NaN                 NaN
# 2      PHY348595  2009-03-21  ...                V08                 NaN
# 3            NaN  2009-06-25  ...              V6441               32723
# 4            NaN  2008-12-24  ...                496                4019
#
#   ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                 NaN               66.0             4019.0
# 1                 NaN               66.0             4019.0
# 2                 NaN               66.0             2724.0
# 3                 NaN               66.0             2724.0
# 4                 NaN             3611.0             2724.0
#
#   ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5 ClmProcedureCode_6  \
# 0             4439.0             4139.0             2724.0                NaN
# 1             4263.0             4139.0             2724.0                NaN
# 2             7823.0             7999.0             4139.0                NaN
# 3             2819.0             4019.0             4139.0                NaN
# 4             4019.0              311.0             4139.0                NaN
#
#   admitted
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 31 columns]

# %% [markdown]
# Merging the IP_OP Dataset with BENE Data

# %%
# Joining the IP_OP dataset with the BENE data
train_ip_op_bene_df = pd.merge(left=train_ip_op_df, right=df_train_bene, left_on='BeneID', right_on='BeneID',how='inner')
train_ip_op_bene_df.shape
# Out:
# (558211, 55)

# %%
# Joining the IP_OP_BENE dataset with the Tgt Label Provider Data
train_iobp_df = pd.merge(left=train_ip_op_bene_df, right=df_train, left_on='Provider', right_on='Provider',how='inner')
train_iobp_df.shape
# Out:
# (558211, 56)

# %% [markdown]
# completed dataset

# %%
train_iobp_df.shape
# Out:
# (558211, 56)

# %%
#unique providers
train_iobp_df['Provider'].nunique()
# Out:
# 5410

# %%
#Unique claims IDs
train_iobp_df['ClaimID'].nunique()
# Out:
# 558211

# %%
# Joining with the PRV Tgt Labels
prvs_claims_df = pd.DataFrame(train_iobp_df.groupby(['Provider'])['ClaimID'].count()).reset_index()
prvs_claims_tgt_lbls_df = pd.merge(left=prvs_claims_df, right=df_train, on='Provider', how='inner')
prvs_claims_tgt_lbls_df
# Out:
#       Provider  ClaimID PotentialFraud
# 0     PRV51001       25             No
# 1     PRV51003      132            Yes
# 2     PRV51004      149             No
# 3     PRV51005     1165            Yes
# 4     PRV51007       72             No
# ...        ...      ...            ...
# 5405  PRV57759       28             No
# 5406  PRV57760       22             No
# 5407  PRV57761       82             No
# 5408  PRV57762        1             No
# 5409  PRV57763      118             No
#
# [5410 rows x 3 columns]

# %%
fig=train_iobp_df['PotentialFraud'].value_counts().plot(kind='bar',color=['green','red'])
for p in fig.patches:
  witdth=p.get_width()
  height=p.get_height()
  x, y =p.get_xy()
  fig.annotate(f'{str(round((height*100)/train_iobp_df.shape[0],2))+"%"}', (x + witdth/2, y + height*1.015), ha='center', fontsize=8.5)

# %% [markdown]
# Insights:
# * from above graph 62% od calims are non-fraud and 32% of them fraudulent.
# * At this point might be a class imbalance problem but after looking at the no. of records it doesn't seem to be a severe class-imbalance problem.
# * by the we use same class imbalance technique inly after training baseline model w/o any synthetic or class weight technique.

# %% [markdown]
# # Feature Enginineering
# * adding feature---2 Is_Alive
# LOGIC:: No if DOD is NaN else Yes

# %%
train_iobp_df['DOB'] = pd.to_datetime(train_iobp_df['DOB'], format="%Y-%m-%d")
train_iobp_df['DOD'] = pd.to_datetime(train_iobp_df['DOD'], format="%Y-%m-%d")

# %%
train_iobp_df['Is_Alive?'] = train_iobp_df['DOD'].apply(lambda val: 'No' if val != val else 'Yes')

# %%
train_iobp_df['Is_Alive?'].value_counts()
# Out:
# Is_Alive?
# No     554080
# Yes      4131
# Name: count, dtype: int64

# %% [markdown]
# * Adding new Feature 3:: Claim_duration
# * LOGIC:: claims end date-Claim start date

# %%
train_iobp_df['ClaimStartDt'] = pd.to_datetime(train_iobp_df['ClaimStartDt'], format="%Y-%m-%d")
train_iobp_df['ClaimEndDt'] = pd.to_datetime(train_iobp_df['ClaimEndDt'], format="%Y-%m-%d")

train_iobp_df['Claim_Duration'] = (train_iobp_df['ClaimEndDt'] - train_iobp_df['ClaimStartDt']).dt.days

# %% [markdown]
# Adding New Feature - 4 :: Admitted_Duration
# LOGIC:Admitted duration= Discharge date-admission date

# %%
train_iobp_df['AdmissionDt'] = pd.to_datetime(train_iobp_df['AdmissionDt'], format="%Y-%m-%d")
train_iobp_df['DischargeDt'] = pd.to_datetime(train_iobp_df['DischargeDt'], format="%Y-%m-%d")

train_iobp_df['Admitted_Duration'] = (train_iobp_df['DischargeDt'] - train_iobp_df['AdmissionDt']).dt.days

# %% [markdown]
# Adding New Feature - 5 :: Bene_Age
# * Bene Age = DOD - DOB (if DOD is Null then replace it with MAX date in DOD)

# %%
# Filling the Null values as MAX Date of Death in the Dataset
train_iobp_df['DOD'].fillna(value=train_iobp_df['DOD'].max(), inplace=True)
# Out:
# /tmp/ipython-input-1545225660.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_iobp_df['DOD'].fillna(value=train_iobp_df['DOD'].max(), inplace=True)

# %%
train_iobp_df['Bene_Age'] = round(((train_iobp_df['DOD'] - train_iobp_df['DOB']).dt.days)/365,1)

# %% [markdown]
# **Adding New Feature - 6 :: Att_Opr_Oth_Phy_Tot_Claims**
# * It represents the total claims submitted by Attending, Operating and Other Physicians.
# * Logic :: Att_Phy_tot_claims + Opr_Phy_tot_claims + Oth_Phy_tot_claims.
# * Att_Phy_tot_claims :: Total Number of claims or cases seen by Attending Physician

# %%
# Total unique number of Attended Physicians
print("Unique number of Attending Physicians present in the dataset are --> {}".format(train_iobp_df['AttendingPhysician'].nunique()))
# Out:
# Unique number of Attending Physicians present in the dataset are --> 82063

# %%
train_iobp_df['Att_Phy_tot_claims'] = train_iobp_df.groupby(['AttendingPhysician'])['ClaimID'].transform('count')
train_iobp_df['Att_Phy_tot_claims'].describe()
# Out:
# count    556703.000000
# mean        138.634829
# std         293.669039
# min           1.000000
# 25%           7.000000
# 50%          33.000000
# 75%         116.000000
# max        2534.000000
# Name: Att_Phy_tot_claims, dtype: float64

# %% [markdown]
# * Opr_Phy_tot_claims :: Total Number of claims or cases seen by Opearting Physician

# %%
# Total unique number of Operating Physicians
print("Unique number of Operating Physicians present in the dataset are --> {}".format(train_iobp_df['OperatingPhysician'].nunique()))
# Out:
# Unique number of Operating Physicians present in the dataset are --> 35315

# %%
train_iobp_df['Opr_Phy_tot_claims'] = train_iobp_df.groupby(['OperatingPhysician'])['ClaimID'].transform('count')
train_iobp_df['Opr_Phy_tot_claims'].describe()
# Out:
# count    114447.000000
# mean         27.204811
# std          52.687759
# min           1.000000
# 25%           2.000000
# 50%           8.000000
# 75%          25.000000
# max         424.000000
# Name: Opr_Phy_tot_claims, dtype: float64

# %% [markdown]
# * Oth_Phy_tot_claims :: Total Number of claims or cases seen by Other Physician

# %%
# Total unique number of Other Physicians
print("Unique number of Other Physicians present in the dataset are --> {}".format(train_iobp_df['OtherPhysician'].nunique()))
# Out:
# Unique number of Other Physicians present in the dataset are --> 46457

# %%
train_iobp_df['Oth_Phy_tot_claims'] = train_iobp_df.groupby(['OtherPhysician'])['ClaimID'].transform('count')
train_iobp_df['Oth_Phy_tot_claims'].describe()
# Out:
# count    199736.000000
# mean         90.207914
# std         208.017235
# min           1.000000
# 25%           3.000000
# 50%          15.000000
# 75%          60.000000
# max        1247.000000
# Name: Oth_Phy_tot_claims, dtype: float64

# %%
# Creating the combined feature
train_iobp_df['Att_Phy_tot_claims'].fillna(value=0, inplace=True)
train_iobp_df['Opr_Phy_tot_claims'].fillna(value=0, inplace=True)
train_iobp_df['Oth_Phy_tot_claims'].fillna(value=0, inplace=True)
# Out:
# /tmp/ipython-input-4095311399.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_iobp_df['Att_Phy_tot_claims'].fillna(value=0, inplace=True)
# /tmp/ipython-input-4095311399.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_iobp_df['Opr_Phy_tot_claims'].fillna(value=0, inplace=True)
# /tmp/ipython-input-4095311399.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_iobp_df['Oth_Phy_tot_claims'].fillna(value=0, inplace=True)

# %%
train_iobp_df['Att_Opr_Oth_Phy_Tot_Claims'] = train_iobp_df['Att_Phy_tot_claims'] + train_iobp_df['Opr_Phy_tot_claims'] + train_iobp_df['Oth_Phy_tot_claims']

# %%
train_iobp_df['Att_Opr_Oth_Phy_Tot_Claims'].describe()
# Out:
# count    558211.000000
# mean        176.115666
# std         379.833208
# min           0.000000
# 25%           9.000000
# 50%          41.000000
# 75%         144.000000
# max        3372.000000
# Name: Att_Opr_Oth_Phy_Tot_Claims, dtype: float64

# %%
train_iobp_df.drop(['Att_Phy_tot_claims', 'Opr_Phy_tot_claims', 'Oth_Phy_tot_claims'], axis=1, inplace=True)

# %% [markdown]
# **Adding New Feature - 7 :: Prv_Tot_Att_Opr_Oth_Phys**
# * It represents the total of all kind of physicians that a provider has interacted with.
# * Logic :: Prv_Tot_Att_Phy + Prv_Tot_Opr_Phy + Prv_Tot_Oth_Phy

# %%
train_iobp_df["Prv_Tot_Att_Phy"] = train_iobp_df.groupby(['Provider'])['AttendingPhysician'].transform('count')
train_iobp_df["Prv_Tot_Opr_Phy"] = train_iobp_df.groupby(['Provider'])['OperatingPhysician'].transform('count')
train_iobp_df["Prv_Tot_Oth_Phy"] = train_iobp_df.groupby(['Provider'])['OtherPhysician'].transform('count')

# %%
# Nulls in the above features
train_iobp_df.isna().sum().tail(3)
# Out:
# Prv_Tot_Att_Phy    0
# Prv_Tot_Opr_Phy    0
# Prv_Tot_Oth_Phy    0
# dtype: int64

# %%
train_iobp_df["Prv_Tot_Att_Phy"].describe()
# Out:
# count    558211.000000
# mean        820.206469
# std        1271.272090
# min           1.000000
# 25%         122.000000
# 50%         359.000000
# 75%        1013.000000
# max        8207.000000
# Name: Prv_Tot_Att_Phy, dtype: float64

# %% [markdown]
# * The average number of attending physicians for providers are 820

# %%
train_iobp_df["Prv_Tot_Opr_Phy"].describe()
# Out:
# count    558211.000000
# mean        155.030023
# std         228.266693
# min           0.000000
# 25%          25.000000
# 50%          73.000000
# 75%         185.000000
# max        1441.000000
# Name: Prv_Tot_Opr_Phy, dtype: float64

# %% [markdown]
# * The average number of operating physicians for providers are 155.

# %%
train_iobp_df["Prv_Tot_Oth_Phy"].describe()
# Out:
# count    558211.000000
# mean        306.781194
# std         497.246984
# min           0.000000
# 25%          37.000000
# 50%         120.000000
# 75%         381.000000
# max        3209.000000
# Name: Prv_Tot_Oth_Phy, dtype: float64

# %% [markdown]
# * The average number of other physicians for providers are 306.

# %%
train_iobp_df['Prv_Tot_Att_Opr_Oth_Phys'] = train_iobp_df['Prv_Tot_Att_Phy'] + train_iobp_df['Prv_Tot_Opr_Phy'] + train_iobp_df['Prv_Tot_Oth_Phy']

# %%
train_iobp_df["Prv_Tot_Att_Opr_Oth_Phys"].describe()
# Out:
# count    558211.000000
# mean       1282.017685
# std        1993.415913
# min           1.000000
# 25%         192.000000
# 50%         560.000000
# 75%        1567.000000
# max       12857.000000
# Name: Prv_Tot_Att_Opr_Oth_Phys, dtype: float64

# %%
train_iobp_df.drop(['Prv_Tot_Att_Phy', 'Prv_Tot_Opr_Phy', 'Prv_Tot_Oth_Phy'], axis=1, inplace=True)

# %% [markdown]
# **Adding New Feature - 8 :: Total Unique Claim Admit Codes used by a PROVIDER**
# * As there may be a pattern that if a provider has used so many Admit Diagnosis Codes then it might increases or decreases the chances of fraud.

# %%
train_iobp_df['PRV_Tot_Admit_DCodes'] = train_iobp_df.groupby(['Provider'])['ClmAdmitDiagnosisCode'].transform('nunique')

# %%
train_iobp_df["PRV_Tot_Admit_DCodes"].describe()
# Out:
# count    558211.000000
# mean        109.227258
# std         112.083238
# min           0.000000
# 25%          28.000000
# 50%          72.000000
# 75%         152.000000
# max         582.000000
# Name: PRV_Tot_Admit_DCodes, dtype: float64

# %% [markdown]
# **Adding New Feature - 9 :: Total Unique Number of Diagnosis Group Codes used by a PROVIDER**
# * As there may be a pattern that if a provider has used so many Diagnosis Group Codes then it might increases or decreases the chances of fraud.

# %%
train_iobp_df['PRV_Tot_DGrpCodes'] = train_iobp_df.groupby(['Provider'])['DiagnosisGroupCode'].transform('nunique')

# %%
train_iobp_df["PRV_Tot_DGrpCodes"].describe()
# Out:
# count    558211.000000
# mean         22.234648
# std          46.571715
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          21.000000
# max         330.000000
# Name: PRV_Tot_DGrpCodes, dtype: float64

# %% [markdown]
# **Adding New Feature - 10 :: Total unique Date of Birth years of beneficiaries provided by a Provider**
# * Because generally private hospitals who treat poor patients make false claims on their names. For example, Nazia is 10 years old. But, according to a claim filed by Chhattisgarh-based Shaheed Hospital with the Rashtriya Swasthya Bima Yojna (RSBY), she has delivered a baby after a caesarean operation. Mukul (name changed) is only 7. But Agarwal Hospital, Raipur, has made a claim for removing cataract from his eyes.
# Read more at: https://economictimes.indiatimes.com/news/politics-and-nation/private-hospitals-perform-fake-surgeries-to-claim-thousands-in-insurance-cover/articleshow/16934229.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst

# %%
train_iobp_df['DOB_Year'] = train_iobp_df['DOB'].dt.year

# %%
train_iobp_df['PRV_Tot_Unq_DOB_Years'] = train_iobp_df.groupby(['Provider'])['DOB_Year'].transform('nunique')

# %%
train_iobp_df['PRV_Tot_Unq_DOB_Years'].describe()
# Out:
# count    558211.000000
# mean         50.615590
# std          18.190988
# min           1.000000
# 25%          38.000000
# 50%          54.000000
# 75%          67.000000
# max          75.000000
# Name: PRV_Tot_Unq_DOB_Years, dtype: float64

# %%
train_iobp_df.drop(['DOB_Year'], axis=1, inplace=True)

# %% [markdown]
# **Adding New Feature - 11 :: Sum of patients age treated by a Provider**

# %%
train_iobp_df['PRV_Bene_Age_Sum'] = train_iobp_df.groupby(['Provider'])['Bene_Age'].transform('sum')

# %%
train_iobp_df['PRV_Bene_Age_Sum'].describe()
# Out:
# count    558211.000000
# mean      60903.124044
# std       95028.202759
# min          34.300000
# 25%        9007.200000
# 50%       26310.800000
# 75%       74869.500000
# max      617454.100000
# Name: PRV_Bene_Age_Sum, dtype: float64

# %% [markdown]
# **Adding New Feature - 12 :: Sum of Insc Claim Re-Imb Amount for a Provider**
# * The idea behind adding this feature is that there might be a pattern like if the sum of claim re-imb amount for a provider is very high or low then it might influence the fraud.

# %%
train_iobp_df['PRV_Insc_Clm_ReImb_Amt'] = train_iobp_df.groupby(['Provider'])['InscClaimAmtReimbursed'].transform('sum')

# %%
train_iobp_df['PRV_Insc_Clm_ReImb_Amt'].describe()
# Out:
# count    5.582110e+05
# mean     4.877429e+05
# std      7.367223e+05
# min      0.000000e+00
# 25%      6.369000e+04
# 50%      2.036000e+05
# 75%      5.969000e+05
# max      5.996050e+06
# Name: PRV_Insc_Clm_ReImb_Amt, dtype: float64

# %% [markdown]
# **Adding New Feature - 13 :: Total number of RKD Patients seen by a Provider**
# * The idea behind adding this feature is that there might be a pattern like if the total number of RKD Patients seen by a Provider is very high or low then it might influence the fraud.

# %%
train_iobp_df['RenalDiseaseIndicator'] = train_iobp_df['RenalDiseaseIndicator'].apply(lambda val: 1 if val == "Y" else 0)

# %%
train_iobp_df['PRV_Tot_RKD_Patients'] = train_iobp_df.groupby(['Provider'])['RenalDiseaseIndicator'].transform('sum')

# %%
train_iobp_df['PRV_Tot_RKD_Patients'].describe()
# Out:
# count    558211.000000
# mean        157.902616
# std         233.828365
# min           0.000000
# 25%          24.000000
# 50%          73.000000
# 75%         192.000000
# max        1447.000000
# Name: PRV_Tot_RKD_Patients, dtype: float64

# %%
# Dropping these 2 columns as there 99% of values are same
train_iobp_df.drop(['NoOfMonths_PartACov', 'NoOfMonths_PartBCov'], axis=1, inplace=True)

# %%
# Filling null values in Admitted_Duration with 0 (as it will represent the patients were admitted for 0 days)
train_iobp_df['Admitted_Duration'].fillna(value=0,inplace=True)
# Out:
# /tmp/ipython-input-1425328035.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_iobp_df['Admitted_Duration'].fillna(value=0,inplace=True)

# %%
train_iobp_df.shape
# Out:
# (558211, 66)

# %% [markdown]
# **Adding Aggregated Features :: For every possible level**
# - Provider
# - Beneficiary
# - Attending Physician
# - Operating Physician
# - Other Physician and etc.

# %%
# PRV Aggregate features
train_iobp_df["PRV_CoPayment"] = train_iobp_df.groupby('Provider')['DeductibleAmtPaid'].transform('sum')
train_iobp_df["PRV_IP_Annual_ReImb_Amt"] = train_iobp_df.groupby('Provider')['IPAnnualReimbursementAmt'].transform('sum')
train_iobp_df["PRV_IP_Annual_Ded_Amt"] = train_iobp_df.groupby('Provider')['IPAnnualDeductibleAmt'].transform('sum')
train_iobp_df["PRV_OP_Annual_ReImb_Amt"] = train_iobp_df.groupby('Provider')['OPAnnualReimbursementAmt'].transform('sum')
train_iobp_df["PRV_OP_Annual_Ded_Amt"] = train_iobp_df.groupby('Provider')['OPAnnualDeductibleAmt'].transform('sum')
train_iobp_df["PRV_Admit_Duration"] = train_iobp_df.groupby('Provider')['Admitted_Duration'].transform('sum')
train_iobp_df["PRV_Claim_Duration"] = train_iobp_df.groupby('Provider')['Claim_Duration'].transform('sum')

# %%
def create_agg_feats(grp_col, feat_name, operation='sum'):
    """
    Description :: This function is created for adding the aggregated features in the dataset for every level like:
        - Beneficiary
        - Attending Physician
        - Operating Physician
        - Other Physician and etc..

    Input Parameters :: It accepts below inputs:
        - grp_col : `str`
            - It represents the feature or level at which you want to perform the aggregation.

        - feat_name : `str`
            - It represents the feature whose aggregated aspect you want to capture.

        - operation : `str`
            - It represents the aggregation operation you want to perform.(By default it is SUM)
    """
    feat_1 = feat_name + "_Insc_ReImb_Amt"
    train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)

    feat_2 = feat_name + "_CoPayment"
    train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)

    feat_3 = feat_name + "_IP_Annual_ReImb_Amt"
    train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)

    feat_4 = feat_name + "_IP_Annual_Ded_Amt"
    train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)

    feat_5 = feat_name + "_OP_Annual_ReImb_Amt"
    train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)

    feat_6 = feat_name + "_OP_Annual_Ded_Amt"
    train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)

    feat_7 = feat_name + "_Admit_Duration"
    train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)

    feat_8 = feat_name + "_Claim_Duration"
    train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)

# %%
# BENE, PHYs, Diagnosis Admit and Group Codes columns
create_agg_feats(grp_col='BeneID', feat_name="BENE")
create_agg_feats(grp_col='AttendingPhysician', feat_name="ATT_PHY")
create_agg_feats(grp_col='OperatingPhysician', feat_name="OPT_PHY")
create_agg_feats(grp_col='OtherPhysician', feat_name="OTH_PHY")
create_agg_feats(grp_col='ClmAdmitDiagnosisCode', feat_name="Claim_Admit_Diag_Code")
create_agg_feats(grp_col='DiagnosisGroupCode', feat_name="Diag_GCode")

# %%
# Dropping these 3 columns as there 99% of values are same
train_iobp_df.drop(['ClmProcedureCode_4', 'ClmProcedureCode_5', 'ClmProcedureCode_6'], axis=1, inplace=True)

# %%
# Diagnosis Codes columns
create_agg_feats(grp_col='ClmDiagnosisCode_1', feat_name="Claim_DiagCode1")
create_agg_feats(grp_col='ClmDiagnosisCode_2', feat_name="Claim_DiagCode2")
create_agg_feats(grp_col='ClmDiagnosisCode_3', feat_name="Claim_DiagCode3")
create_agg_feats(grp_col='ClmDiagnosisCode_4', feat_name="Claim_DiagCode4")
create_agg_feats(grp_col='ClmDiagnosisCode_5', feat_name="Claim_DiagCode5")
create_agg_feats(grp_col='ClmDiagnosisCode_6', feat_name="Claim_DiagCode6")
create_agg_feats(grp_col='ClmDiagnosisCode_7', feat_name="Claim_DiagCode7")
create_agg_feats(grp_col='ClmDiagnosisCode_8', feat_name="Claim_DiagCode8")
create_agg_feats(grp_col='ClmDiagnosisCode_9', feat_name="Claim_DiagCode9")
create_agg_feats(grp_col='ClmDiagnosisCode_10', feat_name="Claim_DiagCode10")
# Out:
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)

# %%
# Medical Procedure Codes columns
create_agg_feats(grp_col='ClmProcedureCode_1', feat_name="Claim_ProcCode1")
create_agg_feats(grp_col='ClmProcedureCode_2', feat_name="Claim_ProcCode2")
create_agg_feats(grp_col='ClmProcedureCode_3', feat_name="Claim_ProcCode3")
# Out:
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_1] = train_iobp_df.groupby(grp_col)['InscClaimAmtReimbursed'].transform(operation)
# /tmp/ipython-input-3368099775.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_2] = train_iobp_df.groupby(grp_col)['DeductibleAmtPaid'].transform(operation)
# /tmp/ipython-input-3368099775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_3] = train_iobp_df.groupby(grp_col)['IPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_4] = train_iobp_df.groupby(grp_col)['IPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_5] = train_iobp_df.groupby(grp_col)['OPAnnualReimbursementAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_6] = train_iobp_df.groupby(grp_col)['OPAnnualDeductibleAmt'].transform(operation)
# /tmp/ipython-input-3368099775.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_7] = train_iobp_df.groupby(grp_col)['Admitted_Duration'].transform(operation)
# /tmp/ipython-input-3368099775.py:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df[feat_8] = train_iobp_df.groupby(grp_col)['Claim_Duration'].transform(operation)

# %%
train_iobp_df.shape
# Out:
# (558211, 222)

# %% [markdown]
# **Adding Aggregated Features**
# * Based on various combinations of different levels in order to introduce their interactions in the dataset.

# %%
# PROVIDER <--> other features :: To get claim counts
train_iobp_df["ClmCount_Provider"]=train_iobp_df.groupby(['Provider'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID"]=train_iobp_df.groupby(['Provider','BeneID'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_AttendingPhysician"]=train_iobp_df.groupby(['Provider','AttendingPhysician'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_OtherPhysician"]=train_iobp_df.groupby(['Provider','OtherPhysician'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_OperatingPhysician"]=train_iobp_df.groupby(['Provider','OperatingPhysician'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmAdmitDiagnosisCode"]=train_iobp_df.groupby(['Provider','ClmAdmitDiagnosisCode'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_10'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_DiagnosisGroupCode"]=train_iobp_df.groupby(['Provider','DiagnosisGroupCode'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-1866289717.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider"]=train_iobp_df.groupby(['Provider'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID"]=train_iobp_df.groupby(['Provider','BeneID'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_AttendingPhysician"]=train_iobp_df.groupby(['Provider','AttendingPhysician'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_OtherPhysician"]=train_iobp_df.groupby(['Provider','OtherPhysician'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_OperatingPhysician"]=train_iobp_df.groupby(['Provider','OperatingPhysician'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmAdmitDiagnosisCode"]=train_iobp_df.groupby(['Provider','ClmAdmitDiagnosisCode'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','ClmDiagnosisCode_10'])['ClaimID'].transform('count')
# /tmp/ipython-input-1866289717.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_DiagnosisGroupCode"]=train_iobp_df.groupby(['Provider','DiagnosisGroupCode'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> PHYSICIANS :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-4246066698.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician'])['ClaimID'].transform('count')
# /tmp/ipython-input-4246066698.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician'])['ClaimID'].transform('count')
# /tmp/ipython-input-4246066698.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> ATTENDING PHYSICIAN <--> PROCEDURE CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_3'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-418793969.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-418793969.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-418793969.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_3'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> OPERATING PHYSICIAN <--> PROCEDURE CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmProcedureCode_3'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-410995603.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-410995603.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-410995603.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmProcedureCode_3'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> OTHER PHYSICIAN <--> PROCEDURE CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmProcedureCode_3'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-485091939.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-485091939.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-485091939.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmProcedureCode_3'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> ATTENDING PHYSICIAN <--> DIAGNOSIS CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_10'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-3131739861.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
# /tmp/ipython-input-3131739861.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_10'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> OPERATING PHYSICIAN <--> DIAGNOSIS CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_10'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-987463178.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
# /tmp/ipython-input-987463178.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','OperatingPhysician','ClmDiagnosisCode_10'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> OTHER PHYSICIAN <--> DIAGNOSIS CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_10'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-1327093911.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
# /tmp/ipython-input-1327093911.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','OtherPhysician','ClmDiagnosisCode_10'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> PROCEDURE CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmProcedureCode_3'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-3241459700.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-3241459700.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-3241459700.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmProcedureCode_3'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> DIAGNOSIS CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-4235424880.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
# /tmp/ipython-input-4235424880.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10'])['ClaimID'].transform('count')

# %%
# PROVIDER <--> BENE <--> DIAGNOSIS CODES <--> PROCEDURE CODES :: To get claim counts
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9','ClmProcedureCode_3'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10','ClmProcedureCode_1'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10','ClmProcedureCode_2'])['ClaimID'].transform('count')
train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10','ClmProcedureCode_3'])['ClaimID'].transform('count')
# Out:
# /tmp/ipython-input-1479647766.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_2','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_3','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_4','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_5','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_6','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_7','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_8','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_9','ClmProcedureCode_3'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_1"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10','ClmProcedureCode_1'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_2"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10','ClmProcedureCode_2'])['ClaimID'].transform('count')
# /tmp/ipython-input-1479647766.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_iobp_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_3"]=train_iobp_df.groupby(['Provider','BeneID','ClmDiagnosisCode_10','ClmProcedureCode_3'])['ClaimID'].transform('count')

# %%
train_iobp_df.shape
# Out:
# (558211, 327)

# %%
# Removing unwanted columns
remove_unwanted_columns=['BeneID', 'ClaimID', 'ClaimStartDt','ClaimEndDt','AttendingPhysician','OperatingPhysician', 'OtherPhysician',
                      'AdmissionDt', 'ClmAdmitDiagnosisCode', 'DischargeDt', 'DiagnosisGroupCode',
                      'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
                      'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10',
                      'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3', 'DOB', 'DOD', 'State', 'County']

train_iobp_df.drop(columns=remove_unwanted_columns, axis=1, inplace=True)

# %%
train_iobp_df.shape
# Out:
# (558211, 299)

# %%
# Filling Nulls in Deductible Amt Paid by Patient
train_iobp_df['DeductibleAmtPaid'].fillna(value=0, inplace=True)
# Out:
# /tmp/ipython-input-4177490351.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_iobp_df['DeductibleAmtPaid'].fillna(value=0, inplace=True)

# %%
# Binary encoding the categorical features --> 0 means No and 1 means Yes
train_iobp_df['Gender'] = train_iobp_df['Gender'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['PotentialFraud'] = train_iobp_df['PotentialFraud'].apply(lambda val: 0 if val == "No" else 1)
train_iobp_df['Is_Alive?'] = train_iobp_df['Is_Alive?'].apply(lambda val: 0 if val == "No" else 1)

train_iobp_df['ChronicCond_Alzheimer'] = train_iobp_df['ChronicCond_Alzheimer'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_Heartfailure'] = train_iobp_df['ChronicCond_Heartfailure'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_KidneyDisease'] = train_iobp_df['ChronicCond_KidneyDisease'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_Cancer'] = train_iobp_df['ChronicCond_Cancer'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_ObstrPulmonary'] = train_iobp_df['ChronicCond_ObstrPulmonary'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_Depression'] = train_iobp_df['ChronicCond_Depression'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_Diabetes'] = train_iobp_df['ChronicCond_Diabetes'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_IschemicHeart'] = train_iobp_df['ChronicCond_IschemicHeart'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_Osteoporasis'] = train_iobp_df['ChronicCond_Osteoporasis'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_rheumatoidarthritis'] = train_iobp_df['ChronicCond_rheumatoidarthritis'].apply(lambda val: 0 if val == 2 else val)
train_iobp_df['ChronicCond_stroke'] = train_iobp_df['ChronicCond_stroke'].apply(lambda val: 0 if val == 2 else val)

# %%
# Encoding the Categorical features
train_iobp_df = pd.get_dummies(train_iobp_df,columns=['Gender', 'Race', 'admitted', 'Is_Alive?'], drop_first=True)

# %%
pd.set_option('display.max_rows',310)

# %%
# Checking Nulls in the features
pd.DataFrame(train_iobp_df.isna().sum())
# Out:
#                                                          0
# Provider                                                 0
# InscClaimAmtReimbursed                                   0
# DeductibleAmtPaid                                        0
# RenalDiseaseIndicator                                    0
# ChronicCond_Alzheimer                                    0
# ChronicCond_Heartfailure                                 0
# ChronicCond_KidneyDisease                                0
# ChronicCond_Cancer                                       0
# ChronicCond_ObstrPulmonary                               0
# ChronicCond_Depression                                   0
# ChronicCond_Diabetes                                     0
# ChronicCond_IschemicHeart                                0
# ChronicCond_Osteoporasis                                 0
# ChronicCond_rheumatoidarthritis                          0
# ChronicCond_stroke                                       0
# IPAnnualReimbursementAmt                                 0
# IPAnnualDeductibleAmt                                    0
# OPAnnualReimbursementAmt                                 0
# OPAnnualDeductibleAmt                                    0
# PotentialFraud                                           0
# Claim_Duration                                           0
# Admitted_Duration                                        0
# Bene_Age                                                 0
# Att_Opr_Oth_Phy_Tot_Claims                               0
# Prv_Tot_Att_Opr_Oth_Phys                                 0
# PRV_Tot_Admit_DCodes                                     0
# PRV_Tot_DGrpCodes                                        0
# PRV_Tot_Unq_DOB_Years                                    0
# PRV_Bene_Age_Sum                                         0
# PRV_Insc_Clm_ReImb_Amt                                   0
# PRV_Tot_RKD_Patients                                     0
# PRV_CoPayment                                            0
# PRV_IP_Annual_ReImb_Amt                                  0
# PRV_IP_Annual_Ded_Amt                                    0
# PRV_OP_Annual_ReImb_Amt                                  0
# PRV_OP_Annual_Ded_Amt                                    0
# PRV_Admit_Duration                                       0
# PRV_Claim_Duration                                       0
# BENE_Insc_ReImb_Amt                                      0
# BENE_CoPayment                                           0
# BENE_IP_Annual_ReImb_Amt                                 0
# BENE_IP_Annual_Ded_Amt                                   0
# BENE_OP_Annual_ReImb_Amt                                 0
# BENE_OP_Annual_Ded_Amt                                   0
# BENE_Admit_Duration                                      0
# BENE_Claim_Duration                                      0
# ATT_PHY_Insc_ReImb_Amt                                1508
# ATT_PHY_CoPayment                                     1508
# ATT_PHY_IP_Annual_ReImb_Amt                           1508
# ATT_PHY_IP_Annual_Ded_Amt                             1508
# ATT_PHY_OP_Annual_ReImb_Amt                           1508
# ATT_PHY_OP_Annual_Ded_Amt                             1508
# ATT_PHY_Admit_Duration                                1508
# ATT_PHY_Claim_Duration                                1508
# OPT_PHY_Insc_ReImb_Amt                              443764
# OPT_PHY_CoPayment                                   443764
# OPT_PHY_IP_Annual_ReImb_Amt                         443764
# OPT_PHY_IP_Annual_Ded_Amt                           443764
# OPT_PHY_OP_Annual_ReImb_Amt                         443764
# OPT_PHY_OP_Annual_Ded_Amt                           443764
# OPT_PHY_Admit_Duration                              443764
# OPT_PHY_Claim_Duration                              443764
# OTH_PHY_Insc_ReImb_Amt                              358475
# OTH_PHY_CoPayment                                   358475
# OTH_PHY_IP_Annual_ReImb_Amt                         358475
# OTH_PHY_IP_Annual_Ded_Amt                           358475
# OTH_PHY_OP_Annual_ReImb_Amt                         358475
# OTH_PHY_OP_Annual_Ded_Amt                           358475
# OTH_PHY_Admit_Duration                              358475
# OTH_PHY_Claim_Duration                              358475
# Claim_Admit_Diag_Code_Insc_ReImb_Amt                412312
# Claim_Admit_Diag_Code_CoPayment                     412312
# Claim_Admit_Diag_Code_IP_Annual_ReImb_Amt           412312
# Claim_Admit_Diag_Code_IP_Annual_Ded_Amt             412312
# Claim_Admit_Diag_Code_OP_Annual_ReImb_Amt           412312
# Claim_Admit_Diag_Code_OP_Annual_Ded_Amt             412312
# Claim_Admit_Diag_Code_Admit_Duration                412312
# Claim_Admit_Diag_Code_Claim_Duration                412312
# Diag_GCode_Insc_ReImb_Amt                           517737
# Diag_GCode_CoPayment                                517737
# Diag_GCode_IP_Annual_ReImb_Amt                      517737
# Diag_GCode_IP_Annual_Ded_Amt                        517737
# Diag_GCode_OP_Annual_ReImb_Amt                      517737
# Diag_GCode_OP_Annual_Ded_Amt                        517737
# Diag_GCode_Admit_Duration                           517737
# Diag_GCode_Claim_Duration                           517737
# Claim_DiagCode1_Insc_ReImb_Amt                       10453
# Claim_DiagCode1_CoPayment                            10453
# Claim_DiagCode1_IP_Annual_ReImb_Amt                  10453
# Claim_DiagCode1_IP_Annual_Ded_Amt                    10453
# Claim_DiagCode1_OP_Annual_ReImb_Amt                  10453
# Claim_DiagCode1_OP_Annual_Ded_Amt                    10453
# Claim_DiagCode1_Admit_Duration                       10453
# Claim_DiagCode1_Claim_Duration                       10453
# Claim_DiagCode2_Insc_ReImb_Amt                      195606
# Claim_DiagCode2_CoPayment                           195606
# Claim_DiagCode2_IP_Annual_ReImb_Amt                 195606
# Claim_DiagCode2_IP_Annual_Ded_Amt                   195606
# Claim_DiagCode2_OP_Annual_ReImb_Amt                 195606
# Claim_DiagCode2_OP_Annual_Ded_Amt                   195606
# Claim_DiagCode2_Admit_Duration                      195606
# Claim_DiagCode2_Claim_Duration                      195606
# Claim_DiagCode3_Insc_ReImb_Amt                      315156
# Claim_DiagCode3_CoPayment                           315156
# Claim_DiagCode3_IP_Annual_ReImb_Amt                 315156
# Claim_DiagCode3_IP_Annual_Ded_Amt                   315156
# Claim_DiagCode3_OP_Annual_ReImb_Amt                 315156
# Claim_DiagCode3_OP_Annual_Ded_Amt                   315156
# Claim_DiagCode3_Admit_Duration                      315156
# Claim_DiagCode3_Claim_Duration                      315156
# Claim_DiagCode4_Insc_ReImb_Amt                      393675
# Claim_DiagCode4_CoPayment                           393675
# Claim_DiagCode4_IP_Annual_ReImb_Amt                 393675
# Claim_DiagCode4_IP_Annual_Ded_Amt                   393675
# Claim_DiagCode4_OP_Annual_ReImb_Amt                 393675
# Claim_DiagCode4_OP_Annual_Ded_Amt                   393675
# Claim_DiagCode4_Admit_Duration                      393675
# Claim_DiagCode4_Claim_Duration                      393675
# Claim_DiagCode5_Insc_ReImb_Amt                      446287
# Claim_DiagCode5_CoPayment                           446287
# Claim_DiagCode5_IP_Annual_ReImb_Amt                 446287
# Claim_DiagCode5_IP_Annual_Ded_Amt                   446287
# Claim_DiagCode5_OP_Annual_ReImb_Amt                 446287
# Claim_DiagCode5_OP_Annual_Ded_Amt                   446287
# Claim_DiagCode5_Admit_Duration                      446287
# Claim_DiagCode5_Claim_Duration                      446287
# Claim_DiagCode6_Insc_ReImb_Amt                      473819
# Claim_DiagCode6_CoPayment                           473819
# Claim_DiagCode6_IP_Annual_ReImb_Amt                 473819
# Claim_DiagCode6_IP_Annual_Ded_Amt                   473819
# Claim_DiagCode6_OP_Annual_ReImb_Amt                 473819
# Claim_DiagCode6_OP_Annual_Ded_Amt                   473819
# Claim_DiagCode6_Admit_Duration                      473819
# Claim_DiagCode6_Claim_Duration                      473819
# Claim_DiagCode7_Insc_ReImb_Amt                      492034
# Claim_DiagCode7_CoPayment                           492034
# Claim_DiagCode7_IP_Annual_ReImb_Amt                 492034
# Claim_DiagCode7_IP_Annual_Ded_Amt                   492034
# Claim_DiagCode7_OP_Annual_ReImb_Amt                 492034
# Claim_DiagCode7_OP_Annual_Ded_Amt                   492034
# Claim_DiagCode7_Admit_Duration                      492034
# Claim_DiagCode7_Claim_Duration                      492034
# Claim_DiagCode8_Insc_ReImb_Amt                      504767
# Claim_DiagCode8_CoPayment                           504767
# Claim_DiagCode8_IP_Annual_ReImb_Amt                 504767
# Claim_DiagCode8_IP_Annual_Ded_Amt                   504767
# Claim_DiagCode8_OP_Annual_ReImb_Amt                 504767
# Claim_DiagCode8_OP_Annual_Ded_Amt                   504767
# Claim_DiagCode8_Admit_Duration                      504767
# Claim_DiagCode8_Claim_Duration                      504767
# Claim_DiagCode9_Insc_ReImb_Amt                      516396
# Claim_DiagCode9_CoPayment                           516396
# Claim_DiagCode9_IP_Annual_ReImb_Amt                 516396
# Claim_DiagCode9_IP_Annual_Ded_Amt                   516396
# Claim_DiagCode9_OP_Annual_ReImb_Amt                 516396
# Claim_DiagCode9_OP_Annual_Ded_Amt                   516396
# Claim_DiagCode9_Admit_Duration                      516396
# Claim_DiagCode9_Claim_Duration                      516396
# Claim_DiagCode10_Insc_ReImb_Amt                     553201
# Claim_DiagCode10_CoPayment                          553201
# Claim_DiagCode10_IP_Annual_ReImb_Amt                553201
# Claim_DiagCode10_IP_Annual_Ded_Amt                  553201
# Claim_DiagCode10_OP_Annual_ReImb_Amt                553201
# Claim_DiagCode10_OP_Annual_Ded_Amt                  553201
# Claim_DiagCode10_Admit_Duration                     553201
# Claim_DiagCode10_Claim_Duration                     553201
# Claim_ProcCode1_Insc_ReImb_Amt                      534901
# Claim_ProcCode1_CoPayment                           534901
# Claim_ProcCode1_IP_Annual_ReImb_Amt                 534901
# Claim_ProcCode1_IP_Annual_Ded_Amt                   534901
# Claim_ProcCode1_OP_Annual_ReImb_Amt                 534901
# Claim_ProcCode1_OP_Annual_Ded_Amt                   534901
# Claim_ProcCode1_Admit_Duration                      534901
# Claim_ProcCode1_Claim_Duration                      534901
# Claim_ProcCode2_Insc_ReImb_Amt                      552721
# Claim_ProcCode2_CoPayment                           552721
# Claim_ProcCode2_IP_Annual_ReImb_Amt                 552721
# Claim_ProcCode2_IP_Annual_Ded_Amt                   552721
# Claim_ProcCode2_OP_Annual_ReImb_Amt                 552721
# Claim_ProcCode2_OP_Annual_Ded_Amt                   552721
# Claim_ProcCode2_Admit_Duration                      552721
# Claim_ProcCode2_Claim_Duration                      552721
# Claim_ProcCode3_Insc_ReImb_Amt                      557242
# Claim_ProcCode3_CoPayment                           557242
# Claim_ProcCode3_IP_Annual_ReImb_Amt                 557242
# Claim_ProcCode3_IP_Annual_Ded_Amt                   557242
# Claim_ProcCode3_OP_Annual_ReImb_Amt                 557242
# Claim_ProcCode3_OP_Annual_Ded_Amt                   557242
# Claim_ProcCode3_Admit_Duration                      557242
# Claim_ProcCode3_Claim_Duration                      557242
# ClmCount_Provider                                        0
# ClmCount_Provider_BeneID                                 0
# ClmCount_Provider_AttendingPhysician                  1508
# ClmCount_Provider_OtherPhysician                    358475
# ClmCount_Provider_OperatingPhysician                443764
# ClmCount_Provider_ClmAdmitDiagnosisCode             412312
# ClmCount_Provider_ClmProcedureCode_1                534901
# ClmCount_Provider_ClmProcedureCode_2                552721
# ClmCount_Provider_ClmProcedureCode_3                557242
# ClmCount_Provider_ClmDiagnosisCode_1                 10453
# ClmCount_Provider_ClmDiagnosisCode_2                195606
# ClmCount_Provider_ClmDiagnosisCode_3                315156
# ClmCount_Provider_ClmDiagnosisCode_4                393675
# ClmCount_Provider_ClmDiagnosisCode_5                446287
# ClmCount_Provider_ClmDiagnosisCode_6                473819
# ClmCount_Provider_ClmDiagnosisCode_7                492034
# ClmCount_Provider_ClmDiagnosisCode_8                504767
# ClmCount_Provider_ClmDiagnosisCode_9                516396
# ClmCount_Provider_ClmDiagnosisCode_10               553201
# ClmCount_Provider_DiagnosisGroupCode                517737
# ClmCount_Provider_BeneID_AttendingPhysician           1508
# ClmCount_Provider_BeneID_OtherPhysician             358475
# ClmCount_Provider_BeneID_OperatingPhysician         443764
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  534955
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  552731
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  557243
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  534967
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  552732
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  557244
# ClmCount_Provider_BeneID_OtherPhysician_ClmProc...  554852
# ClmCount_Provider_BeneID_OtherPhysician_ClmProc...  557245
# ClmCount_Provider_BeneID_OtherPhysician_ClmProc...  558042
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...   11924
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  196536
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  315773
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  394100
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  446561
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  474019
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  492192
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  504895
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  516483
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  553202
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  444934
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  467643
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  485054
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  498950
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  510204
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  518108
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  524563
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  529702
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  534931
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  554888
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  362184
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  429018
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  473339
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  503049
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  523311
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  533463
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  540145
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  544636
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  548410
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  557003
# ClmCount_Provider_BeneID_ClmProcedureCode_1         534901
# ClmCount_Provider_BeneID_ClmProcedureCode_2         552721
# ClmCount_Provider_BeneID_ClmProcedureCode_3         557242
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1          10453
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2         195606
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3         315156
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4         393675
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5         446287
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6         473819
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7         492034
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8         504767
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9         516396
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10        553201
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_Clm...  534901
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_Clm...  552721
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_Clm...  557242
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_Clm...  535014
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_Clm...  552737
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_Clm...  557243
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_Clm...  535283
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_Clm...  552771
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_Clm...  557246
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_Clm...  535776
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_Clm...  552847
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_Clm...  557262
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_Clm...  536530
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_Clm...  553011
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_Clm...  557291
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_Clm...  537559
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_Clm...  553224
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_Clm...  557319
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_Clm...  538851
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_Clm...  553533
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_Clm...  557371
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_Clm...  540240
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_Clm...  553860
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_Clm...  557423
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_Clm...  542161
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_Clm...  554266
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_Clm...  557489
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_Cl...  555507
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_Cl...  557513
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_Cl...  558075
# Gender_1                                                 0
# Race_2                                                   0
# Race_3                                                   0
# Race_5                                                   0
# admitted_1                                               0
# Is_Alive?_1                                              0

# %%
# Filling Nulls in the aggregated features
train_iobp_df.fillna(value=0, inplace=True)

# %%
# Checking Nulls in the features
pd.DataFrame(train_iobp_df.isna().sum())
# Out:
#                                                     0
# Provider                                            0
# InscClaimAmtReimbursed                              0
# DeductibleAmtPaid                                   0
# RenalDiseaseIndicator                               0
# ChronicCond_Alzheimer                               0
# ChronicCond_Heartfailure                            0
# ChronicCond_KidneyDisease                           0
# ChronicCond_Cancer                                  0
# ChronicCond_ObstrPulmonary                          0
# ChronicCond_Depression                              0
# ChronicCond_Diabetes                                0
# ChronicCond_IschemicHeart                           0
# ChronicCond_Osteoporasis                            0
# ChronicCond_rheumatoidarthritis                     0
# ChronicCond_stroke                                  0
# IPAnnualReimbursementAmt                            0
# IPAnnualDeductibleAmt                               0
# OPAnnualReimbursementAmt                            0
# OPAnnualDeductibleAmt                               0
# PotentialFraud                                      0
# Claim_Duration                                      0
# Admitted_Duration                                   0
# Bene_Age                                            0
# Att_Opr_Oth_Phy_Tot_Claims                          0
# Prv_Tot_Att_Opr_Oth_Phys                            0
# PRV_Tot_Admit_DCodes                                0
# PRV_Tot_DGrpCodes                                   0
# PRV_Tot_Unq_DOB_Years                               0
# PRV_Bene_Age_Sum                                    0
# PRV_Insc_Clm_ReImb_Amt                              0
# PRV_Tot_RKD_Patients                                0
# PRV_CoPayment                                       0
# PRV_IP_Annual_ReImb_Amt                             0
# PRV_IP_Annual_Ded_Amt                               0
# PRV_OP_Annual_ReImb_Amt                             0
# PRV_OP_Annual_Ded_Amt                               0
# PRV_Admit_Duration                                  0
# PRV_Claim_Duration                                  0
# BENE_Insc_ReImb_Amt                                 0
# BENE_CoPayment                                      0
# BENE_IP_Annual_ReImb_Amt                            0
# BENE_IP_Annual_Ded_Amt                              0
# BENE_OP_Annual_ReImb_Amt                            0
# BENE_OP_Annual_Ded_Amt                              0
# BENE_Admit_Duration                                 0
# BENE_Claim_Duration                                 0
# ATT_PHY_Insc_ReImb_Amt                              0
# ATT_PHY_CoPayment                                   0
# ATT_PHY_IP_Annual_ReImb_Amt                         0
# ATT_PHY_IP_Annual_Ded_Amt                           0
# ATT_PHY_OP_Annual_ReImb_Amt                         0
# ATT_PHY_OP_Annual_Ded_Amt                           0
# ATT_PHY_Admit_Duration                              0
# ATT_PHY_Claim_Duration                              0
# OPT_PHY_Insc_ReImb_Amt                              0
# OPT_PHY_CoPayment                                   0
# OPT_PHY_IP_Annual_ReImb_Amt                         0
# OPT_PHY_IP_Annual_Ded_Amt                           0
# OPT_PHY_OP_Annual_ReImb_Amt                         0
# OPT_PHY_OP_Annual_Ded_Amt                           0
# OPT_PHY_Admit_Duration                              0
# OPT_PHY_Claim_Duration                              0
# OTH_PHY_Insc_ReImb_Amt                              0
# OTH_PHY_CoPayment                                   0
# OTH_PHY_IP_Annual_ReImb_Amt                         0
# OTH_PHY_IP_Annual_Ded_Amt                           0
# OTH_PHY_OP_Annual_ReImb_Amt                         0
# OTH_PHY_OP_Annual_Ded_Amt                           0
# OTH_PHY_Admit_Duration                              0
# OTH_PHY_Claim_Duration                              0
# Claim_Admit_Diag_Code_Insc_ReImb_Amt                0
# Claim_Admit_Diag_Code_CoPayment                     0
# Claim_Admit_Diag_Code_IP_Annual_ReImb_Amt           0
# Claim_Admit_Diag_Code_IP_Annual_Ded_Amt             0
# Claim_Admit_Diag_Code_OP_Annual_ReImb_Amt           0
# Claim_Admit_Diag_Code_OP_Annual_Ded_Amt             0
# Claim_Admit_Diag_Code_Admit_Duration                0
# Claim_Admit_Diag_Code_Claim_Duration                0
# Diag_GCode_Insc_ReImb_Amt                           0
# Diag_GCode_CoPayment                                0
# Diag_GCode_IP_Annual_ReImb_Amt                      0
# Diag_GCode_IP_Annual_Ded_Amt                        0
# Diag_GCode_OP_Annual_ReImb_Amt                      0
# Diag_GCode_OP_Annual_Ded_Amt                        0
# Diag_GCode_Admit_Duration                           0
# Diag_GCode_Claim_Duration                           0
# Claim_DiagCode1_Insc_ReImb_Amt                      0
# Claim_DiagCode1_CoPayment                           0
# Claim_DiagCode1_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode1_IP_Annual_Ded_Amt                   0
# Claim_DiagCode1_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode1_OP_Annual_Ded_Amt                   0
# Claim_DiagCode1_Admit_Duration                      0
# Claim_DiagCode1_Claim_Duration                      0
# Claim_DiagCode2_Insc_ReImb_Amt                      0
# Claim_DiagCode2_CoPayment                           0
# Claim_DiagCode2_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode2_IP_Annual_Ded_Amt                   0
# Claim_DiagCode2_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode2_OP_Annual_Ded_Amt                   0
# Claim_DiagCode2_Admit_Duration                      0
# Claim_DiagCode2_Claim_Duration                      0
# Claim_DiagCode3_Insc_ReImb_Amt                      0
# Claim_DiagCode3_CoPayment                           0
# Claim_DiagCode3_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode3_IP_Annual_Ded_Amt                   0
# Claim_DiagCode3_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode3_OP_Annual_Ded_Amt                   0
# Claim_DiagCode3_Admit_Duration                      0
# Claim_DiagCode3_Claim_Duration                      0
# Claim_DiagCode4_Insc_ReImb_Amt                      0
# Claim_DiagCode4_CoPayment                           0
# Claim_DiagCode4_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode4_IP_Annual_Ded_Amt                   0
# Claim_DiagCode4_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode4_OP_Annual_Ded_Amt                   0
# Claim_DiagCode4_Admit_Duration                      0
# Claim_DiagCode4_Claim_Duration                      0
# Claim_DiagCode5_Insc_ReImb_Amt                      0
# Claim_DiagCode5_CoPayment                           0
# Claim_DiagCode5_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode5_IP_Annual_Ded_Amt                   0
# Claim_DiagCode5_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode5_OP_Annual_Ded_Amt                   0
# Claim_DiagCode5_Admit_Duration                      0
# Claim_DiagCode5_Claim_Duration                      0
# Claim_DiagCode6_Insc_ReImb_Amt                      0
# Claim_DiagCode6_CoPayment                           0
# Claim_DiagCode6_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode6_IP_Annual_Ded_Amt                   0
# Claim_DiagCode6_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode6_OP_Annual_Ded_Amt                   0
# Claim_DiagCode6_Admit_Duration                      0
# Claim_DiagCode6_Claim_Duration                      0
# Claim_DiagCode7_Insc_ReImb_Amt                      0
# Claim_DiagCode7_CoPayment                           0
# Claim_DiagCode7_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode7_IP_Annual_Ded_Amt                   0
# Claim_DiagCode7_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode7_OP_Annual_Ded_Amt                   0
# Claim_DiagCode7_Admit_Duration                      0
# Claim_DiagCode7_Claim_Duration                      0
# Claim_DiagCode8_Insc_ReImb_Amt                      0
# Claim_DiagCode8_CoPayment                           0
# Claim_DiagCode8_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode8_IP_Annual_Ded_Amt                   0
# Claim_DiagCode8_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode8_OP_Annual_Ded_Amt                   0
# Claim_DiagCode8_Admit_Duration                      0
# Claim_DiagCode8_Claim_Duration                      0
# Claim_DiagCode9_Insc_ReImb_Amt                      0
# Claim_DiagCode9_CoPayment                           0
# Claim_DiagCode9_IP_Annual_ReImb_Amt                 0
# Claim_DiagCode9_IP_Annual_Ded_Amt                   0
# Claim_DiagCode9_OP_Annual_ReImb_Amt                 0
# Claim_DiagCode9_OP_Annual_Ded_Amt                   0
# Claim_DiagCode9_Admit_Duration                      0
# Claim_DiagCode9_Claim_Duration                      0
# Claim_DiagCode10_Insc_ReImb_Amt                     0
# Claim_DiagCode10_CoPayment                          0
# Claim_DiagCode10_IP_Annual_ReImb_Amt                0
# Claim_DiagCode10_IP_Annual_Ded_Amt                  0
# Claim_DiagCode10_OP_Annual_ReImb_Amt                0
# Claim_DiagCode10_OP_Annual_Ded_Amt                  0
# Claim_DiagCode10_Admit_Duration                     0
# Claim_DiagCode10_Claim_Duration                     0
# Claim_ProcCode1_Insc_ReImb_Amt                      0
# Claim_ProcCode1_CoPayment                           0
# Claim_ProcCode1_IP_Annual_ReImb_Amt                 0
# Claim_ProcCode1_IP_Annual_Ded_Amt                   0
# Claim_ProcCode1_OP_Annual_ReImb_Amt                 0
# Claim_ProcCode1_OP_Annual_Ded_Amt                   0
# Claim_ProcCode1_Admit_Duration                      0
# Claim_ProcCode1_Claim_Duration                      0
# Claim_ProcCode2_Insc_ReImb_Amt                      0
# Claim_ProcCode2_CoPayment                           0
# Claim_ProcCode2_IP_Annual_ReImb_Amt                 0
# Claim_ProcCode2_IP_Annual_Ded_Amt                   0
# Claim_ProcCode2_OP_Annual_ReImb_Amt                 0
# Claim_ProcCode2_OP_Annual_Ded_Amt                   0
# Claim_ProcCode2_Admit_Duration                      0
# Claim_ProcCode2_Claim_Duration                      0
# Claim_ProcCode3_Insc_ReImb_Amt                      0
# Claim_ProcCode3_CoPayment                           0
# Claim_ProcCode3_IP_Annual_ReImb_Amt                 0
# Claim_ProcCode3_IP_Annual_Ded_Amt                   0
# Claim_ProcCode3_OP_Annual_ReImb_Amt                 0
# Claim_ProcCode3_OP_Annual_Ded_Amt                   0
# Claim_ProcCode3_Admit_Duration                      0
# Claim_ProcCode3_Claim_Duration                      0
# ClmCount_Provider                                   0
# ClmCount_Provider_BeneID                            0
# ClmCount_Provider_AttendingPhysician                0
# ClmCount_Provider_OtherPhysician                    0
# ClmCount_Provider_OperatingPhysician                0
# ClmCount_Provider_ClmAdmitDiagnosisCode             0
# ClmCount_Provider_ClmProcedureCode_1                0
# ClmCount_Provider_ClmProcedureCode_2                0
# ClmCount_Provider_ClmProcedureCode_3                0
# ClmCount_Provider_ClmDiagnosisCode_1                0
# ClmCount_Provider_ClmDiagnosisCode_2                0
# ClmCount_Provider_ClmDiagnosisCode_3                0
# ClmCount_Provider_ClmDiagnosisCode_4                0
# ClmCount_Provider_ClmDiagnosisCode_5                0
# ClmCount_Provider_ClmDiagnosisCode_6                0
# ClmCount_Provider_ClmDiagnosisCode_7                0
# ClmCount_Provider_ClmDiagnosisCode_8                0
# ClmCount_Provider_ClmDiagnosisCode_9                0
# ClmCount_Provider_ClmDiagnosisCode_10               0
# ClmCount_Provider_DiagnosisGroupCode                0
# ClmCount_Provider_BeneID_AttendingPhysician         0
# ClmCount_Provider_BeneID_OtherPhysician             0
# ClmCount_Provider_BeneID_OperatingPhysician         0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmProc...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmProc...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmProc...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_AttendingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OperatingPhysician_Clm...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiag...  0
# ClmCount_Provider_BeneID_ClmProcedureCode_1         0
# ClmCount_Provider_BeneID_ClmProcedureCode_2         0
# ClmCount_Provider_BeneID_ClmProcedureCode_3         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9         0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10        0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_Clm...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_Cl...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_Cl...  0
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_Cl...  0
# Gender_1                                            0
# Race_2                                              0
# Race_3                                              0
# Race_5                                              0
# admitted_1                                          0
# Is_Alive?_1                                         0

# %%
train_iobp_df.dtypes
# Out:
# Provider                                                            object
# InscClaimAmtReimbursed                                               int64
# DeductibleAmtPaid                                                  float64
# RenalDiseaseIndicator                                                int64
# ChronicCond_Alzheimer                                                int64
# ChronicCond_Heartfailure                                             int64
# ChronicCond_KidneyDisease                                            int64
# ChronicCond_Cancer                                                   int64
# ChronicCond_ObstrPulmonary                                           int64
# ChronicCond_Depression                                               int64
# ChronicCond_Diabetes                                                 int64
# ChronicCond_IschemicHeart                                            int64
# ChronicCond_Osteoporasis                                             int64
# ChronicCond_rheumatoidarthritis                                      int64
# ChronicCond_stroke                                                   int64
# IPAnnualReimbursementAmt                                             int64
# IPAnnualDeductibleAmt                                                int64
# OPAnnualReimbursementAmt                                             int64
# OPAnnualDeductibleAmt                                                int64
# PotentialFraud                                                       int64
# Claim_Duration                                                       int64
# Admitted_Duration                                                  float64
# Bene_Age                                                           float64
# Att_Opr_Oth_Phy_Tot_Claims                                         float64
# Prv_Tot_Att_Opr_Oth_Phys                                             int64
# PRV_Tot_Admit_DCodes                                                 int64
# PRV_Tot_DGrpCodes                                                    int64
# PRV_Tot_Unq_DOB_Years                                                int64
# PRV_Bene_Age_Sum                                                   float64
# PRV_Insc_Clm_ReImb_Amt                                               int64
# PRV_Tot_RKD_Patients                                                 int64
# PRV_CoPayment                                                      float64
# PRV_IP_Annual_ReImb_Amt                                              int64
# PRV_IP_Annual_Ded_Amt                                                int64
# PRV_OP_Annual_ReImb_Amt                                              int64
# PRV_OP_Annual_Ded_Amt                                                int64
# PRV_Admit_Duration                                                 float64
# PRV_Claim_Duration                                                   int64
# BENE_Insc_ReImb_Amt                                                  int64
# BENE_CoPayment                                                     float64
# BENE_IP_Annual_ReImb_Amt                                             int64
# BENE_IP_Annual_Ded_Amt                                               int64
# BENE_OP_Annual_ReImb_Amt                                             int64
# BENE_OP_Annual_Ded_Amt                                               int64
# BENE_Admit_Duration                                                float64
# BENE_Claim_Duration                                                  int64
# ATT_PHY_Insc_ReImb_Amt                                             float64
# ATT_PHY_CoPayment                                                  float64
# ATT_PHY_IP_Annual_ReImb_Amt                                        float64
# ATT_PHY_IP_Annual_Ded_Amt                                          float64
# ATT_PHY_OP_Annual_ReImb_Amt                                        float64
# ATT_PHY_OP_Annual_Ded_Amt                                          float64
# ATT_PHY_Admit_Duration                                             float64
# ATT_PHY_Claim_Duration                                             float64
# OPT_PHY_Insc_ReImb_Amt                                             float64
# OPT_PHY_CoPayment                                                  float64
# OPT_PHY_IP_Annual_ReImb_Amt                                        float64
# OPT_PHY_IP_Annual_Ded_Amt                                          float64
# OPT_PHY_OP_Annual_ReImb_Amt                                        float64
# OPT_PHY_OP_Annual_Ded_Amt                                          float64
# OPT_PHY_Admit_Duration                                             float64
# OPT_PHY_Claim_Duration                                             float64
# OTH_PHY_Insc_ReImb_Amt                                             float64
# OTH_PHY_CoPayment                                                  float64
# OTH_PHY_IP_Annual_ReImb_Amt                                        float64
# OTH_PHY_IP_Annual_Ded_Amt                                          float64
# OTH_PHY_OP_Annual_ReImb_Amt                                        float64
# OTH_PHY_OP_Annual_Ded_Amt                                          float64
# OTH_PHY_Admit_Duration                                             float64
# OTH_PHY_Claim_Duration                                             float64
# Claim_Admit_Diag_Code_Insc_ReImb_Amt                               float64
# Claim_Admit_Diag_Code_CoPayment                                    float64
# Claim_Admit_Diag_Code_IP_Annual_ReImb_Amt                          float64
# Claim_Admit_Diag_Code_IP_Annual_Ded_Amt                            float64
# Claim_Admit_Diag_Code_OP_Annual_ReImb_Amt                          float64
# Claim_Admit_Diag_Code_OP_Annual_Ded_Amt                            float64
# Claim_Admit_Diag_Code_Admit_Duration                               float64
# Claim_Admit_Diag_Code_Claim_Duration                               float64
# Diag_GCode_Insc_ReImb_Amt                                          float64
# Diag_GCode_CoPayment                                               float64
# Diag_GCode_IP_Annual_ReImb_Amt                                     float64
# Diag_GCode_IP_Annual_Ded_Amt                                       float64
# Diag_GCode_OP_Annual_ReImb_Amt                                     float64
# Diag_GCode_OP_Annual_Ded_Amt                                       float64
# Diag_GCode_Admit_Duration                                          float64
# Diag_GCode_Claim_Duration                                          float64
# Claim_DiagCode1_Insc_ReImb_Amt                                     float64
# Claim_DiagCode1_CoPayment                                          float64
# Claim_DiagCode1_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode1_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode1_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode1_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode1_Admit_Duration                                     float64
# Claim_DiagCode1_Claim_Duration                                     float64
# Claim_DiagCode2_Insc_ReImb_Amt                                     float64
# Claim_DiagCode2_CoPayment                                          float64
# Claim_DiagCode2_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode2_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode2_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode2_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode2_Admit_Duration                                     float64
# Claim_DiagCode2_Claim_Duration                                     float64
# Claim_DiagCode3_Insc_ReImb_Amt                                     float64
# Claim_DiagCode3_CoPayment                                          float64
# Claim_DiagCode3_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode3_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode3_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode3_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode3_Admit_Duration                                     float64
# Claim_DiagCode3_Claim_Duration                                     float64
# Claim_DiagCode4_Insc_ReImb_Amt                                     float64
# Claim_DiagCode4_CoPayment                                          float64
# Claim_DiagCode4_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode4_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode4_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode4_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode4_Admit_Duration                                     float64
# Claim_DiagCode4_Claim_Duration                                     float64
# Claim_DiagCode5_Insc_ReImb_Amt                                     float64
# Claim_DiagCode5_CoPayment                                          float64
# Claim_DiagCode5_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode5_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode5_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode5_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode5_Admit_Duration                                     float64
# Claim_DiagCode5_Claim_Duration                                     float64
# Claim_DiagCode6_Insc_ReImb_Amt                                     float64
# Claim_DiagCode6_CoPayment                                          float64
# Claim_DiagCode6_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode6_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode6_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode6_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode6_Admit_Duration                                     float64
# Claim_DiagCode6_Claim_Duration                                     float64
# Claim_DiagCode7_Insc_ReImb_Amt                                     float64
# Claim_DiagCode7_CoPayment                                          float64
# Claim_DiagCode7_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode7_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode7_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode7_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode7_Admit_Duration                                     float64
# Claim_DiagCode7_Claim_Duration                                     float64
# Claim_DiagCode8_Insc_ReImb_Amt                                     float64
# Claim_DiagCode8_CoPayment                                          float64
# Claim_DiagCode8_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode8_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode8_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode8_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode8_Admit_Duration                                     float64
# Claim_DiagCode8_Claim_Duration                                     float64
# Claim_DiagCode9_Insc_ReImb_Amt                                     float64
# Claim_DiagCode9_CoPayment                                          float64
# Claim_DiagCode9_IP_Annual_ReImb_Amt                                float64
# Claim_DiagCode9_IP_Annual_Ded_Amt                                  float64
# Claim_DiagCode9_OP_Annual_ReImb_Amt                                float64
# Claim_DiagCode9_OP_Annual_Ded_Amt                                  float64
# Claim_DiagCode9_Admit_Duration                                     float64
# Claim_DiagCode9_Claim_Duration                                     float64
# Claim_DiagCode10_Insc_ReImb_Amt                                    float64
# Claim_DiagCode10_CoPayment                                         float64
# Claim_DiagCode10_IP_Annual_ReImb_Amt                               float64
# Claim_DiagCode10_IP_Annual_Ded_Amt                                 float64
# Claim_DiagCode10_OP_Annual_ReImb_Amt                               float64
# Claim_DiagCode10_OP_Annual_Ded_Amt                                 float64
# Claim_DiagCode10_Admit_Duration                                    float64
# Claim_DiagCode10_Claim_Duration                                    float64
# Claim_ProcCode1_Insc_ReImb_Amt                                     float64
# Claim_ProcCode1_CoPayment                                          float64
# Claim_ProcCode1_IP_Annual_ReImb_Amt                                float64
# Claim_ProcCode1_IP_Annual_Ded_Amt                                  float64
# Claim_ProcCode1_OP_Annual_ReImb_Amt                                float64
# Claim_ProcCode1_OP_Annual_Ded_Amt                                  float64
# Claim_ProcCode1_Admit_Duration                                     float64
# Claim_ProcCode1_Claim_Duration                                     float64
# Claim_ProcCode2_Insc_ReImb_Amt                                     float64
# Claim_ProcCode2_CoPayment                                          float64
# Claim_ProcCode2_IP_Annual_ReImb_Amt                                float64
# Claim_ProcCode2_IP_Annual_Ded_Amt                                  float64
# Claim_ProcCode2_OP_Annual_ReImb_Amt                                float64
# Claim_ProcCode2_OP_Annual_Ded_Amt                                  float64
# Claim_ProcCode2_Admit_Duration                                     float64
# Claim_ProcCode2_Claim_Duration                                     float64
# Claim_ProcCode3_Insc_ReImb_Amt                                     float64
# Claim_ProcCode3_CoPayment                                          float64
# Claim_ProcCode3_IP_Annual_ReImb_Amt                                float64
# Claim_ProcCode3_IP_Annual_Ded_Amt                                  float64
# Claim_ProcCode3_OP_Annual_ReImb_Amt                                float64
# Claim_ProcCode3_OP_Annual_Ded_Amt                                  float64
# Claim_ProcCode3_Admit_Duration                                     float64
# Claim_ProcCode3_Claim_Duration                                     float64
# ClmCount_Provider                                                    int64
# ClmCount_Provider_BeneID                                             int64
# ClmCount_Provider_AttendingPhysician                               float64
# ClmCount_Provider_OtherPhysician                                   float64
# ClmCount_Provider_OperatingPhysician                               float64
# ClmCount_Provider_ClmAdmitDiagnosisCode                            float64
# ClmCount_Provider_ClmProcedureCode_1                               float64
# ClmCount_Provider_ClmProcedureCode_2                               float64
# ClmCount_Provider_ClmProcedureCode_3                               float64
# ClmCount_Provider_ClmDiagnosisCode_1                               float64
# ClmCount_Provider_ClmDiagnosisCode_2                               float64
# ClmCount_Provider_ClmDiagnosisCode_3                               float64
# ClmCount_Provider_ClmDiagnosisCode_4                               float64
# ClmCount_Provider_ClmDiagnosisCode_5                               float64
# ClmCount_Provider_ClmDiagnosisCode_6                               float64
# ClmCount_Provider_ClmDiagnosisCode_7                               float64
# ClmCount_Provider_ClmDiagnosisCode_8                               float64
# ClmCount_Provider_ClmDiagnosisCode_9                               float64
# ClmCount_Provider_ClmDiagnosisCode_10                              float64
# ClmCount_Provider_DiagnosisGroupCode                               float64
# ClmCount_Provider_BeneID_AttendingPhysician                        float64
# ClmCount_Provider_BeneID_OtherPhysician                            float64
# ClmCount_Provider_BeneID_OperatingPhysician                        float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_1         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_2         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmProcedureCode_3         float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_1     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_2     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_3     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_4     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_5     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_6     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_7     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_8     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_9     float64
# ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_10    float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_1     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_2     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_3     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_4     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_5     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_6     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_7     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_8     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_9     float64
# ClmCount_Provider_BeneID_OperatingPhysician_ClmDiagnosisCode_10    float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_1         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_2         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_3         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_4         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_5         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_6         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_7         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_8         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_9         float64
# ClmCount_Provider_BeneID_OtherPhysician_ClmDiagnosisCode_10        float64
# ClmCount_Provider_BeneID_ClmProcedureCode_1                        float64
# ClmCount_Provider_BeneID_ClmProcedureCode_2                        float64
# ClmCount_Provider_BeneID_ClmProcedureCode_3                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9                        float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10                       float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_2_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_3_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_4_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_5_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_6_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_7_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_8_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_1     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_2     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_9_ClmProcedureCode_3     float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_1    float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_2    float64
# ClmCount_Provider_BeneID_ClmDiagnosisCode_10_ClmProcedureCode_3    float64
# Gender_1                                                              bool
# Race_2                                                                bool
# Race_3                                                                bool
# Race_5                                                                bool
# admitted_1                                                            bool
# Is_Alive?_1                                                           bool
# dtype: object

# %%
train_iobp_df.shape
# Out:
# (558211, 301)

# %%
train_iobp_df = train_iobp_df.groupby(['Provider','PotentialFraud'],as_index=False).agg('sum')

# %%
train_iobp_df.shape
# Out:
# (5410, 301)

# %%
#saving the data for model
train_iobp_df.to_csv('train_iobp_df1.csv', index=False)

# %% [markdown]
# Creating separate sets of independent features and target column.
